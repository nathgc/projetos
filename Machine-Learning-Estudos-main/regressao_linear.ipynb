# %% [markdown]
# <a href="https://colab.research.google.com/github/nathgc/Machine-Learning-Estudos/blob/main/regressao_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exemplo original Extraído do "Hands on Machine Learning ..." terceira edição (inglês)

# %%
# Importando bibliotecas
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# Download and prepare the data
data_root = "https://github.com/ageron/data/raw/main/"
# Lendo dados
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values
# Visualize the data
lifesat.plot(kind='scatter', grid=True,
x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
plt.show()
# Select a linear model
model = LinearRegression()
# Train the model
model.fit(X, y)
# Make a prediction for Cyprus
X_new = [[37_655.2]] # Cyprus' GDP per capita in 2020
print(model.predict(X_new)) # output: [[6.30165767]]
model.score(X,y)
# Out:
# [[6.30165767]]
# 0.7272610933272652

# %%
lifesat
# Out:
#            Country  GDP per capita (USD)  Life satisfaction
# 0           Russia          26456.387938                5.8
# 1           Greece          27287.083401                5.4
# 2           Turkey          28384.987785                5.5
# 3           Latvia          29932.493910                5.9
# 4          Hungary          31007.768407                5.6
# 5         Portugal          32181.154537                5.4
# 6           Poland          32238.157259                6.1
# 7          Estonia          35638.421351                5.7
# 8            Spain          36215.447591                6.3
# 9         Slovenia          36547.738956                5.9
# 10       Lithuania          36732.034744                5.9
# 11          Israel          38341.307570                7.2
# 12           Italy          38992.148381                6.0
# 13  United Kingdom          41627.129269                6.8
# 14          France          42025.617373                6.5
# ...

# %% [markdown]
# # Exemplo com algumas modificações e comentários

# %%
# Importando bibliotecas
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# Download and prepare the data
data_root = "https://raw.githubusercontent.com/ageron/data/main/"
# Lendo dados
lifesat = pd.read_csv(data_root + "lifesat/lifesat_full.csv")
# Atribuindo a X e y colunas dos dados e transformando em arrays os dados
X = lifesat[["GDP per capita (USD)"]].to_numpy()
y = lifesat[["Life satisfaction"]].to_numpy()
# Visualize the data
#plotando os dados usando
lifesat.plot(kind='scatter', grid=True,
x="GDP per capita (USD)", y="Life satisfaction")
# Definindo limites nos eixos X e y.
plt.axis([23_500, 62_500, 4, 9])
#mostrando tudo
plt.show()
# Select a linear model
model = LinearRegression()
# Train the model
model.fit(X, y)
# Make a prediction for Cyprus
X_new = [[37_655.2]] # Cyprus' GDP per capita in 2020
print(model.predict(X_new)) # output: [[6.30165767]]
model.score(X,y) # Coeficiente R^2 de ajuste do modelo
# Out:
# [[6.45909437]]
# 0.36094744655972066

# %%
X
# Out:
# array([[ 11466.18967158],
#        [ 13441.49295226],
#        [ 14063.98250538],
#        [ 17887.7507357 ],
#        [ 23324.52475065],
#        [ 26456.38793813],
#        [ 27287.08340093],
#        [ 28384.98778463],
#        [ 29932.49391006],
#        [ 31007.76840654],
#        [ 32181.15453723],
#        [ 32238.15725928],
#        [ 35638.42135118],
#        [ 36215.44759073],
#        [ 36547.73895598],
#        [ 36732.03474403],
#        [ 38341.30757041],
#        [ 38992.14838075],
#        [ 41627.12926943],
#        [ 42025.61737306],
#        [ 42404.39373816],
#        [ 45856.62562648],
#        [ 47260.80045844],
#        [ 48210.03311134],
#        [ 48697.83702825],
#        [ 50683.32350972],
#        [ 50922.35802345],
#        [ 51935.60386182],
#        [ 52279.72885136],
#        [ 54209.56383573],
#        [ 55938.2128086 ],
#        [ 60235.7284917 ],
#        [ 63585.9035143 ],
#        [ 68393.30600395],
#        [ 89688.95695849],
# ...
